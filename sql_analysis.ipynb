# %%
# !pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in ./opt/anaconda3/lib/python3.7/site-packages (0.3.9)
# Requirement already satisfied: sqlparse in ./opt/anaconda3/lib/python3.7/site-packages (from ipython-sql) (0.3.1)
# Requirement already satisfied: sqlalchemy>=0.6.7 in ./opt/anaconda3/lib/python3.7/site-packages (from ipython-sql) (1.3.9)
# Requirement already satisfied: ipython>=1.0 in ./opt/anaconda3/lib/python3.7/site-packages (from ipython-sql) (7.8.0)
# Requirement already satisfied: six in ./opt/anaconda3/lib/python3.7/site-packages (from ipython-sql) (1.12.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in ./opt/anaconda3/lib/python3.7/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: prettytable in ./opt/anaconda3/lib/python3.7/site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: traitlets>=4.2 in ./opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (4.3.3)
# Requirement already satisfied: pexpect; sys_platform != "win32" in ./opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (4.7.0)
# Requirement already satisfied: pickleshare in ./opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: appnope; sys_platform == "darwin" in ./opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.1.0)
# Requirement already satisfied: backcall in ./opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.1.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in ./opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (2.0.10)
# Requirement already satisfied: pygments in ./opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (2.4.2)
# Requirement already satisfied: jedi>=0.10 in ./opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.15.1)
# Requirement already satisfied: setuptools>=18.5 in ./opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (41.4.0)
# Requirement already satisfied: decorator in ./opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (4.4.0)
# Requirement already satisfied: ptyprocess>=0.5 in ./opt/anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=1.0->ipython-sql) (0.6.0)
# Requirement already satisfied: wcwidth in ./opt/anaconda3/lib/python3.7/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.1.7)
# Requirement already satisfied: parso>=0.5.0 in ./opt/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython>=1.0->ipython-sql) (0.5.1)

# %%
# !pip install pymysql
# Out:
# Requirement already satisfied: pymysql in ./opt/anaconda3/lib/python3.7/site-packages (0.9.3)

# %%
# %load_ext sql

# %%
# %sql mysql://USERNAME:PASSWORD@HOST/DATABASE
# Out:
# 'Connected: admin@sql_project'

# %% [markdown]
# The most frequent kind of accident that the American C-130 experiences
# is an Accident Type 1 (A1), where a crash results in a total hull loss.
# This is followed by accident type C1, a sabotage or shootdown resulting in a hull loss, and O1 which is either a ground fire or sabotage.

# %% [markdown]
# SQL Exploratory Question, Business Justification, and Statement(s) #1:
#
# QUESTION:
# The first question I seek to answer is: which operators of the American C130 airframe have the worst safety records? Obviously, this is a somewhat loaded question in the sense that there are far more variables to investigate than those from the data we currently possess.
#
# SQL STATEMENT:
# We can get more information by knowing the plane's registration, and for ease of data processing and memory considerations let us first clean the data a bit with this in mind. We will use a CTE and a CASE for this. The CASE will be used such that the data is readily interpretable without a key or legend.
#
# BUSINESS JUSTIFICATION:
# Knowing which operators of the C130 have the worst safety record provides an opportunity for Lockheed Martin (the producer of the aircraft) or other defense contracting/pilot training firms to identify potential customers that could use extra training. This not only could generate revenue for the company that identifies this opportunity but also will save lives and standardize that operator's level of interoperability.

# %%
# %%sql
# WITH CTE_Known_Registrations AS (
# 	SELECT *
# 	FROM c130_1)
# SELECT *,
# CASE
#     WHEN cat = 'a1' THEN 'Accident resulted in a total hull loss'
#     WHEN cat = 'a2' THEN 'Accident resulted in a partial hull loss'
#     WHEN cat = 'c1' THEN 'Full hull loss resulting from a sabotage or shootdown'
#     WHEN cat = 'c2' THEN 'Partial hull loss resulting from a sabotage or shootdown'
#     WHEN cat = 'o1' THEN 'Full hull loss resulting from a ground fire or sabotage'
#     WHEN cat = 'o2' THEN 'Partial hull loss resulting from a ground fire or sabotage'
#     ELSE 'Hull status after incident is unknown'
# END AS Category_Explanation
# FROM CTE_Known_Registrations
# 	WHERE registration != '';
# Out:
#  * mysql://admin:***@lmu-sql.cj7ti7dehqfe.us-east-2.rds.amazonaws.com/sql_project
# 272 rows affected.
# [('5-Aug-08', 'Lockheed C-130H Hercules', '1212', 'United Arab Emirates AF', 0, 'Bagram Air B...', 'A1', 1, 'Accident resulted in a total hull loss'),
#  ('24-Feb-09', 'Lockheed C-130H Hercules', 'SU-BAC/1272', 'Egyptian AF', 0, 'unknown', 'A1', 2, 'Accident resulted in a total hull loss'),
#  ('11-May-09', 'Lockheed C-130B Hercules', 'A-1302', 'Indonesian AF', 0, 'Wamena Airpo...', 'A1', 3, 'Accident resulted in a total hull loss'),
#  ('29-Oct-09', 'Lockheed HC-130H Hercules', '1705', 'US Coast Guard', 7, 'near San Clemente...', 'A1', 4, 'Accident resulted in a total hull loss'),
#  ('23-Nov-09', 'Lockheed KC-130J Hercules', 'MM62176', 'Italian AF', 5, 'Le Rene, nea...', 'A1', 5, 'Accident resulted in a total hull loss'),
#  ('25-Jan-10', 'Lockheed C-130B Hercules', '404', 'South African AF', 0, 'Waterkloof A...', 'A1', 6, 'Accident resulted in a total hull loss'),
#  ('2-Feb-10', 'Lockheed C-130E Hercules', '1506', 'Polish AF', 0, 'Mazar-I-Shar...', 'A2', 7, 'Accident resulted in a partial hull loss'),
#  ('6-May-10', 'Lockheed Hercules C.3A (C-130K)', 'XV304', 'RAF', 0, 'Brize Norton...', 'A1', 8, 'Accident resulted in a total hull loss'),
#  ('18-Nov-10', 'Lockheed C-130H Hercules', '7O-ADD/1160', 'Yemen AF', 0, "Sana'a Inter...", 'A2', 9, 'Accident resulted in a partial hull loss'),
#  ('19-Nov-10', 'Lockheed C-130H-30 Hercules', '7T-WHA', 'Algerian AF', 0, 'Paris-Le Bou...', 'A2', 10, 'Accident resulted in a partial hull loss'),
#  ('25-Apr-11', 'Lockheed C-130E Hercules', '62-1806', 'USAF', 0, 'Jacksonville...', 'O1', 11, 'Full hull loss resulting from a ground fire or sabotage'),
#  ('25-Apr-11', 'Lockheed C-130E Hercules', '62-1851', 'USAF', 0, 'Jacksonville...', 'O1', 12, 'Full hull loss resulting from a ground fire or sabotage'),
#  ('26-Jul-11', 'Lockheed C-130H Hercules', 'CNA-OQ', 'Moroccan AF', 80, 'near Goulimime Ai...', 'A1', 13, 'Accident resulted in a total hull loss'),
#  ('21-Feb-12', 'Lockheed CC-130H(T) Hercules', '130342', 'RCAF', 0, 'Key West NAS...', 'A1', 15, 'Accident resulted in a total hull loss'),
#  ('15-Mar-12', 'Lockheed C-130J-30 Super Hercules', '5630', 'Norwegian AF', 5, 'Mount Kebnek...', 'A1', 16, 'Accident resulted in a total hull loss'),
#  ('1-Jul-12', 'Lockheed C-130H Hercules', '93-1458', 'USAF', 4, 'near Edgemont, SD', 'A1', 17, 'Accident resulted in a total hull loss'),
#  ('11-Dec-12', 'Lockheed HC-130P Hercules', '65-0981', 'USAF', None, 'within Afghanistan', 'U1', 18, 'Hull status after incident is unknown'),
#  ('19-May-13', 'Lockheed C-130J-30 Super Hercules', 'Apr-44', 'USAF', 0, 'Forward Oper...', 'A1', 19, 'Accident resulted in a total hull loss'),
#  ('??-MAY-2013', 'Lockheed C-130H Hercules', 'T.10-02', 'Spanish AF', 0, 'unknown', 'U1', 20, 'Hull status after incident is unknown'),
#  ('11-Feb-14', 'Lockheed C-130H-30 Hercules', '7T-WHM', 'Algerian AF', 76, 'near Aïn Kercha', 'A1', 21, 'Accident resulted in a total hull loss'),
#  ('28-Mar-14', 'Lockheed C-130J-30 Super Hercules', 'KC-3803', 'Indian AF', 5, 'Karauli dist...', 'A1', 22, 'Accident resulted in a total hull loss'),
#  ('22-Jul-14', 'Lockheed C-130J Super Hercules', 'MM62190', 'Italian AF', 0, 'Herat Airpor...', 'A1', 23, 'Accident resulted in a total hull loss'),
#  ('21-Sep-14', 'Lockheed C-130H Hercules', 'SU-BAT/1287', 'Egyptian AF', 6, 'Kom Ashwin, ...', 'A1', 24, 'Accident resulted in a total hull loss'),
#  ('27-Nov-14', 'Lockheed C-130M Hercules', '2470', 'Brazilian AF', 0, 'Teniente Rod...', 'A2', 25, 'Accident resulted in a partial hull loss'),
#  ('1-Dec-14', 'Lockheed C-130H Hercules', '88-4404', 'USAF', 0, 'near Mackall AAF, NC', 'A1', 26, 'Accident resulted in a total hull loss'),
#  ('13-Apr-15', 'Lockheed NC-130F Hercules', '148897', 'USMC', 0, 'Port Hueneme...', 'A1', 27, 'Accident resulted in a total hull loss'),
#  ('21-Apr-15', 'Lockheed AC-130J Ghostrider', '10-Sep', 'USAF', 0, 'near Valparaiso-E...', 'A1', 28, 'Accident resulted in a total hull loss'),
#  ('30-Jun-15', 'Lockheed C-130B Hercules', 'A-1310', 'Indonesian AF', 139, 'near Medan-Soewon...', 'A1', 29, 'Accident resulted in a total hull loss'),
#  ('7-Jul-15', 'Lockheed C-130H Hercules', '79-0478', 'USAF', 0, 'Baghdad Inte...', 'A1', 30, 'Accident resulted in a total hull loss'),
#  ('2-Oct-15', 'Lockheed C-130J-30 Super Hercules', 'Aug-74', 'USAF', 14, 'Jalalabad Ai...', 'A1', 31, 'Accident resulted in a total hull loss'),
#  ('11-Jul-16', 'Lockheed C-130H Hercules', '16804', 'Portuguese AF', 3, 'Montijo Air ...', 'A1', 32, 'Accident resulted in a total hull loss'),
#  ('19-Oct-16', 'Lockheed C-130B Hercules', 'FAC-1014', 'Colombian AF', 1, 'near Apiay', 'A1', 33, 'Accident resulted in a total hull loss'),
#  ('18-Dec-16', 'Lockheed C-130H Hercules', 'A-1334', 'Indonesian AF', 13, 'near Wamena Airpo...', 'A1', 34, 'Accident resulted in a total hull loss'),
#  ('10-Jul-17', 'Lockheed KC-130T Hercules', '165000', 'USMC', 16, 'near Itta Bena, MS', 'A1', 35, 'Accident resulted in a total hull loss'),
#  ('25-Aug-17', 'Lockheed Hercules C.4 (C-130J-30)', 'ZH873', 'RAF', 0, 'Temporary La...', 'A1', 36, 'Accident resulted in a total hull loss'),
#  ('2-May-18', 'Lockheed WC-130H Hercules', '65-0968', 'USAF', 9, 'near Savannah/Hil...', 'A1', 38, 'Accident resulted in a total hull loss'),
#  ('3-Jun-18', 'Lockheed C-130H Hercules', '7T-WHT', 'Algerian AF', 1, 'near Biskra Airpo...', 'A1', 39, 'Accident resulted in a total hull loss'),
#  ('9-Nov-18', 'Lockheed C-130E Hercules', '4180', 'Pakistan AF', 0, 'Chaklala-PAF...', 'A1', 40, 'Accident resulted in a total hull loss'),
#  ('6-Dec-18', 'Lockheed Martin KC-130J', '167981', 'USMC', 5, 'near Muroto Cape,...', 'A1', 41, 'Accident resulted in a total hull loss'),
#  ('25-Aug-19', 'Lockheed C-130A Hercules', 'N119TG', 'International Air Response', 0, 'Santa Barbar...', 'A2', 42, 'Accident resulted in a partial hull loss'),
#  ('9-Dec-19', 'Lockheed C-130H Hercules', '990', 'Chilean AF', 38, 'near King George ...', 'A1', 43, 'Accident resulted in a total hull loss'),
#  ('9-Jan-20', 'Lockheed C-130BZ Hercules', '403', 'South African AF', 0, 'Goma Airport...', 'A1', 44, 'Accident resulted in a total hull loss'),
#  ('23-Jan-20', 'Lockheed EC-130Q Hercules', 'N134CG', 'Coulson Aviation', 3, 'near Cooma, NSW', 'A1', 45, 'Accident resulted in a total hull loss'),
#  ('2-Oct-70', 'Lockheed C-130E Hercules', '64-0536', 'USAF', 43, 'near Taipei', 'A1', 46, 'Accident resulted in a total hull loss'),
#  ('15-Feb-71', 'Lockheed LC-130F Hercules', '148318', 'US Navy', 0, 'McMurdo-Will...', 'A1', 47, 'Accident resulted in a total hull loss'),
#  ('21-Feb-71', 'Lockheed C-130B Hercules', '61-2642', 'USAF', 0, 'Da Nang Airp...', 'O1', 48, 'Full hull loss resulting from a ground fire or sabotage'),
#  ('9-Nov-71', 'Lockheed Hercules C.1 (C-130K)', 'XV216', 'RAF', 52, 'near Pisa-San Giu...', 'A1', 49, 'Accident resulted in a total hull loss'),
#  ('12-Nov-71', 'Lockheed C-130E Hercules', '69-6578', 'USAF', 10, 'Jacksonville...', 'A1', 50, 'Accident resulted in a total hull loss'),
#  ('4-Dec-71', 'Lockheed LC-130F Hercules', '148321', 'US Navy', 0, 'D-59 Station', 'A2', 51, 'Accident resulted in a partial hull loss'),
#  ('15-Jan-72', 'Lockheed KC-130F Hercules', '149810', 'USMC', None, 'Lake City, FL', 'O1', 52, 'Full hull loss resulting from a ground fire or sabotage'),
#  ('15-Jan-72', 'Lockheed EC-130G Hercules', '151890', 'US Navy', 0, 'near Patuxent Riv...', 'A1', 53, 'Accident resulted in a total hull loss'),
#  ('19-Feb-72', 'Lockheed C-130E Hercules', '62-1813', 'USAF', 5, 'near Jacksonville...', 'A1', 54, 'Accident resulted in a total hull loss'),
#  ('28-Mar-72', 'Lockheed AC-130A Spectre', '55-0044', 'USAF', 14, 'near Tchepone', 'C1', 55, 'Full hull loss resulting from a sabotage or shootdown'),
#  ('30-Mar-72', 'Lockheed AC-130E Spectre', '69-6571', 'USAF', 0, 'near Saravane', 'C1', 56, 'Full hull loss resulting from a sabotage or shootdown'),
#  ('18-Apr-72', 'Lockheed C-130E Hercules', '63-7775', 'USAF', 0, 'near Lai Khe', 'C1', 57, 'Full hull loss resulting from a sabotage or shootdown'),
#  ('26-Apr-72', 'Lockheed C-130E Hercules', '64-0508', 'USAF', 6, 'near An Loc', 'C1', 58, 'Full hull loss resulting from a sabotage or shootdown'),
#  ('3-May-72', 'Lockheed C-130E Hercules', '62-1797', 'USAF', 6, 'near An Loc', 'C1', 59, 'Full hull loss resulting from a sabotage or shootdown'),
#  ('17-May-72', 'Lockheed C-130E Hercules', '63-7798', 'USAF', 4, 'near Kontum Airpo...', 'C1', 60, 'Full hull loss resulting from a sabotage or shootdown'),
#  ('23-May-72', 'Lockheed C-130E Hercules', '62-1854', 'USAF', 0, 'Kontum Airpo...', 'O1', 61, 'Full hull loss resulting from a ground fire or sabotage'),
#  ('5-Jun-72', 'Lockheed C-130D Hercules', '57-0495', 'USAF', 1, 'DYE 3 Airstrip', 'A1', 62, 'Accident resulted in a total hull loss'),
#  ('5-Jun-72', 'Lockheed C-130E Hercules', '62-1805', 'USAF', 6, 'near Magong AFB (...', 'A1', 63, 'Accident resulted in a total hull loss'),
#  ('18-Jun-72', 'Lockheed AC-130A Spectre', '55-0043', 'USAF', 12, 'near A Shau Valley', 'C1', 64, 'Full hull loss resulting from a sabotage or shootdown'),
#  ('12-Aug-72', 'Lockheed C-130E Hercules', '62-1853', 'USAF', 30, 'near Soc Trang (SOA)', 'C1', 65, 'Full hull loss resulting from a sabotage or shootdown'),
#  ('12-Sep-72', 'Lockheed Hercules C.1 (C-130K)', 'XV194', 'RAF', 0, 'Tromsø/Langn...', 'A1', 66, 'Accident resulted in a total hull loss'),
#  ('5-Dec-72', 'Lockheed C-130E-I Hercules', '64-0558', 'USAF', 12, 'near Conway, SC', 'A1', 67, 'Accident resulted in a total hull loss'),
#  ('9-Dec-72', 'Lockheed C-130E Hercules', '64-0505', 'USAF', 5, 'Guam-Agana N...', 'A1', 68, 'Accident resulted in a total hull loss'),
#  ('21-Dec-72', 'Lockheed AC-130A Spectre', '56-0490', 'USAF', 14, 'near Pakse', 'C1', 69, 'Full hull loss resulting from a sabotage or shootdown'),
#  ('28-Jan-73', 'Lockheed LC-130R Hercules', '155917', 'US Navy', 0, 'South Pole S...', 'A1', 70, 'Accident resulted in a total hull loss'),
#  ('10-Sep-73', 'Lockheed Hercules C.1 (C-130K)', 'XV198', 'RAF', 5, 'Colerne RAF ...', 'A1', 71, 'Accident resulted in a total hull loss'),
#  ('15-Oct-73', 'Lockheed C-130E Hercules', '62-1845', 'USAF', 7, 'Sugar Loaf M...', 'A1', 72, 'Accident resulted in a total hull loss'),
#  ('28-Feb-74', 'Lockheed C-130E Hercules', '5-122', 'Iran AF', 10, 'near Tehran-Mehra...', 'A1', 73, 'Accident resulted in a total hull loss'),
#  ('20-Apr-74', 'Lockheed C-130E Hercules', '62-1841', 'USAF', 6, 'Guam-Agana N...', 'A1', 74, 'Accident resulted in a total hull loss'),
#  ('18-Aug-74', 'Lockheed C-130H Hercules', '9T-TCD', 'Zaire AF', 31, 'near Kisangani', 'A1', 75, 'Accident resulted in a total hull loss'),
#  ('30-Sep-74', 'Lockheed C-130E Hercules', '63-7802', 'USAF', None, 'Okinawa-Kade...', 'A1', 76, 'Accident resulted in a total hull loss'),
#  ('13-Oct-74', 'Lockheed WC-130H Hercules', '65-0965', 'USAF', 6, 'near Clark Air Ba...', 'A1', 77, 'Accident resulted in a total hull loss'),
#  ('18-Dec-74', 'Lockheed C-130A Hercules', '56-0521', 'Vietnam Air Force - VNAF', None, 'Song Be', 'O1', 78, 'Full hull loss resulting from a ground fire or sabotage'),
#  ('25-Dec-74', 'Lockheed C-130A Hercules', '55-0016', 'Vietnam Air Force - VNAF', None, 'Song Be', 'C1', 79, 'Full hull loss resulting from a sabotage or shootdown'),
#  ('2-Jan-75', 'Lockheed C-130B Hercules', '58-0721', 'USAF', 2, 'New Orleans ...', 'A1', 80, 'Accident resulted in a total hull loss'),
#  ('6-Apr-75', 'Lockheed C-130A Hercules', '55-0002', 'Vietnam Air Force - VNAF', 0, 'Bien Hoa', 'A1', 81, 'Accident resulted in a total hull loss'),
#  ('28-Apr-75', 'Lockheed C-130E Hercules', '72-1297', 'USAF', 0, 'Saigon-Tan S...', 'O1', 82, 'Full hull loss resulting from a ground fire or sabotage'),
#  ('??-APR-1975', 'Lockheed C-130A Hercules', '55-0045', 'USAF', None, '', 'U1', 83, 'Hull status after incident is unknown'),
#  ('??-APR-1975', 'Lockheed C-130A Hercules', '56-0542', 'Vietnam Air Force - VNAF', None, '', 'U1', 84, 'Hull status after incident is unknown'),
#  ('??-APR-1975', 'Lockheed C-130A Hercules', '57-0465', 'Vietnam Air Force - VNAF', None, '', 'U1', 85, 'Hull status after incident is unknown'),
#  ('??-APR-1975', 'Lockheed C-130A Hercules', '55-0006', 'Vietnam Air Force - VNAF', None, '', 'U1', 86, 'Hull status after incident is unknown'),
#  ('??-APR-1975', 'Lockheed C-130A Hercules', '56-0489', 'Vietnam Air Force - VNAF', None, '', 'U1', 87, 'Hull status after incident is unknown'),
#  ('??-APR-1975', 'Lockheed C-130A Hercules', '56-0505', 'Vietnam Air Force - VNAF', None, '', 'U1', 88, 'Hull status after incident is unknown'),
#  ('26-Jul-75', 'Lockheed C-130A Hercules', '57-0454', 'USAF', 6, 'near Imlay City, MI', 'A1', 89, 'Accident resulted in a total hull loss'),
#  ('28-Aug-75', 'Lockheed C-130E Hercules', 'TC-62', 'Argentine AF', 4, 'Tucumán Airp...', 'C1', 90, 'Full hull loss resulting from a sabotage or shootdown'),
#  ('25-Nov-75', 'Lockheed C-130H Hercules', '4X-FBC/203', 'Israeli AF', 20, 'near El Arish', 'A1', 91, 'Accident resulted in a total hull loss'),
#  ('3-Sep-76', 'Lockheed C-130H Hercules', '7772', 'Venezuela AF', 68, 'near Terceira-Laj...', 'A1', 92, 'Accident resulted in a total hull loss'),
#  ('4-Dec-76', 'Lockheed C-130H Hercules', 'CN-AOB', 'Moroccan AF', None, 'near Laayoune-Has...', 'C1', 93, 'Full hull loss resulting from a sabotage or shootdown'),
#  ('21-Dec-76', 'Lockheed C-130H Hercules', 'May-36', 'Iran AF', 9, 'near Shiraz Airpo...', 'A1', 94, 'Accident resulted in a total hull loss'),
#  ('3-Mar-77', 'Lockheed C-130H Hercules', 'MM61996', 'Italian AF', 44, 'near Pisa-Arturo ...', 'A1', 95, 'Accident resulted in a total hull loss'),
#  ('21-Jun-77', 'Lockheed EC-130Q Hercules', '156176', 'US Navy', 16, 'near Wake Island ...', 'A1', 96, 'Accident resulted in a total hull loss'),
#  ('19-Feb-78', 'Lockheed C-130H Hercules', 'SU-BAA/1270', 'Egyptian AF', 3, 'Larnaca Airp...', 'C1', 97, 'Full hull loss resulting from a sabotage or shootdown'),
#  ('15-Apr-78', 'Lockheed C-130E Hercules', '63-7787', 'USAF', 2, 'near Fort Irwin-B...', 'A1', 98, 'Accident resulted in a total hull loss'),
#  ('28-Apr-78', 'Lockheed C-130E Hercules', '63-7766', 'USAF', 7, 'Sparrevohn A...', 'A1', 99, 'Accident resulted in a total hull loss'),
#  ('12-Jul-78', 'Lockheed C-130H Hercules', 'FAE748', 'Ecuador Air Force', 11, 'Pichincha Mo...', 'A1', 100, 'Accident resulted in a total hull loss'),
#  ('8-Sep-78', 'Lockheed C-130E Hercules', '64-0532', 'USAF', 8, 'Conway, AR', 'A1', 101, 'Accident resulted in a total hull loss'),
#  ('19-Sep-78', 'Lockheed C-130H Hercules', 'May-32', 'Iran AF', 9, 'Tehran/Dosha...', 'A1', 102, 'Accident resulted in a total hull loss'),
#  ('30-Nov-78', 'Lockheed C-130E Hercules', '68-10936', 'USAF', 6, 'near Cottageville...', 'A1', 103, 'Accident resulted in a total hull loss'),
#  ('10-Dec-78', 'Lockheed C-130E Hercules', '68-10951', 'USAF', 5, 'near Hopkinsville...', 'A1', 104, 'Accident resulted in a total hull loss'),
#  ('23-Jan-79', 'Lockheed C-130H Hercules', 'MM62000', 'Italian AF', 0, 'Milano-Malpe...', 'O1', 105, 'Full hull loss resulting from a ground fire or sabotage'),
#  ('1-Feb-79', 'Lockheed C-130E Hercules', '10687', 'Pakistan AF', 0, 'Lahore Airpo...', 'O1', 106, 'Full hull loss resulting from a ground fire or sabotage'),
#  ('1-Feb-79', 'Lockheed C-130B Hercules', '23488', 'Pakistan AF', 0, 'Lahore Airpo...', 'O1', 107, 'Full hull loss resulting from a ground fire or sabotage'),
#  ('8-Apr-79', 'Lockheed C-130H Hercules', '116', 'Libyan Arab Rep. Air Force', 0, 'Entebbe Airp...', 'O1', 108, 'Full hull loss resulting from a ground fire or sabotage'),
#  ('19-Jun-79', 'Lockheed C-130E Hercules', '20-May', 'Iran AF', 5, 'near Shiraz', 'A1', 109, 'Accident resulted in a total hull loss'),
#  ('28-Sep-79', 'Lockheed C-130H Hercules', 'CP-1375', 'TAB', 4, 'near Panama City-...', 'A1', 110, 'Accident resulted in a total hull loss'),
#  ('14-Mar-80', 'Lockheed C-130H Hercules', '74-2064', 'USAF', 18, 'near Adana-Incirl...', 'A1', 111, 'Accident resulted in a total hull loss'),
#  ('24-Apr-80', 'Lockheed EC-130E Hercules', '62-1809', 'USAF', 5, 'Posht-i-Badam', 'A1', 112, 'Accident resulted in a total hull loss'),
#  ('28-May-80', 'Lockheed C-130H Hercules', 'T.10-1', 'Spanish AF', 10, 'near Las Palmas-G...', 'A1', 113, 'Accident resulted in a total hull loss'),
#  ('14-Sep-80', 'Lockheed C-130E Hercules', '453', 'Saudi AF', 89, 'near Madinah-Moha...', 'A1', 114, 'Accident resulted in a total hull loss'),
#  ('14-Sep-80', 'Lockheed C-130H Hercules', '9T-TCE', 'Zaire AF', 36, 'Kindu Airpor...', 'A1', 115, 'Accident resulted in a total hull loss'),
#  ('2-Oct-80', 'Lockheed C-130A Hercules', '56-0504', 'USAF', 4, 'McMinnville, TN', 'A1', 116, 'Accident resulted in a total hull loss'),
#  ('15-Oct-80', 'Lockheed CC-130E Hercules', '130312', 'Canadian Armed Forces', 8, 'near Chapais, QC', 'A1', 117, 'Accident resulted in a total hull loss'),
#  ('29-Oct-80', 'Lockheed YMC-130H Hercules', '74-1683', 'USAF', 0, 'Valparaiso-W...', 'A1', 118, 'Accident resulted in a total hull loss'),
#  ('4-Nov-80', 'Lockheed C-130H Hercules', '3556', 'Venezuela AF', 11, 'near Caracas-Simó...', 'A1', 119, 'Accident resulted in a total hull loss'),
#  ('14-Jan-81', 'Lockheed C-130E Hercules', '69-6581', 'USAF', 9, 'Ramstein AFB...', 'A1', 120, 'Accident resulted in a total hull loss'),
#  ('26-Feb-81', 'Lockheed MC-130E Combat Talon I', '64-0564', 'USAF', 23, 'near Tabones Island', 'A1', 121, 'Accident resulted in a total hull loss'),
#  ('29-May-81', 'Lockheed C-130H Hercules', 'SU-BAH/1276', 'Egyptian AF', 17, 'near Cairo West A...', 'A1', 122, 'Accident resulted in a total hull loss'),
#  ('21-Sep-81', 'Lockheed C-130H Hercules', '74-1672', 'USAF', 7, 'near Indian Sprin...', 'A1', 123, 'Accident resulted in a total hull loss'),
#  ('29-Sep-81', 'Lockheed C-130H Hercules', 'May-52', 'Iran AF', 80, 'Kahrisak', 'A1', 124, 'Accident resulted in a total hull loss'),
#  ('12-Oct-81', 'Lockheed C-130H Hercules', 'CNA-OH', 'Moroccan AF', 5, 'Guelta Zammour', 'C1', 125, 'Full hull loss resulting from a sabotage or shootdown'),
#  ('13-Apr-82', 'Lockheed C-130H Hercules', '74-1678', 'USAF', 27, 'near Gevenlik', 'A1', 126, 'Accident resulted in a total hull loss'),
#  ('29-Apr-82', 'Lockheed C-130H Hercules', 'HC-BEF/FAE74', 'Ecuador Air Force', 7, 'near Quito-Marisc...', 'A1', 127, 'Accident resulted in a total hull loss'),
#  ('12-May-82', 'Lockheed C-130E Hercules', '64-0543', 'USAF', 7, 'Judsonia, AR', 'A1', 128, 'Accident resulted in a total hull loss'),
#  ('1-Jun-82', 'Lockheed C-130H Hercules', 'TC-63', 'Argentine AF', 7, 'near Pebble Island', 'C1', 129, 'Full hull loss resulting from a sabotage or shootdown'),
#  ('30-Jul-82', 'Lockheed HC-130H Hercules', '1600', 'US Coast Guard', 2, 'near Attu Island-...', 'A1', 130, 'Accident resulted in a total hull loss'),
#  ('16-Oct-82', 'Lockheed C-130B Hercules', 'FAC-1003', 'Colombian AF', 5, 'near Cape May, NJ...', 'A1', 131, 'Accident resulted in a total hull loss'),
#  ('16-Nov-82', 'Lockheed CC-130H Hercules', '130329', 'Canadian Armed Forces', 7, 'Edmonton-Nam...', 'A1', 132, 'Accident resulted in a total hull loss'),
#  ('13-Feb-83', 'Lockheed C-130H Hercules', '74-1693', 'USAF', 6, 'Fayetteville...', 'A1', 133, 'Accident resulted in a total hull loss'),
#  ('28-Jun-83', 'Lockheed C-130H Hercules', '74-2068', 'USAF', 6, 'near Las Vegas-Ne...', 'A1', 134, 'Accident resulted in a total hull loss'),
#  ('28-Feb-84', 'Lockheed C-130E Hercules', '68-10944', 'USAF', 18, 'near Borja', 'A1', 135, 'Accident resulted in a total hull loss'),
#  ('2-Nov-84', 'Lockheed C-130E Hercules', '68-10946', 'USAF', 0, 'Giebelstadt ...', 'A1', 136, 'Accident resulted in a total hull loss'),
#  ('22-Jan-85', 'Lockheed C-130A Hercules', '56-0501', 'USAF', 21, 'near Trujillo-Cap...', 'A1', 137, 'Accident resulted in a total hull loss'),
#  ('24-Feb-85', 'Lockheed KC-130H Hercules', '1620', 'Saudi AF', 8, 'Riyadh Air B...', 'A1', 138, 'Accident resulted in a total hull loss'),
#  ('12-Mar-85', 'Lockheed C-130E Hercules', '64-0549', 'USAF', 6, 'Fort Hood, TX', 'A1', 140, 'Accident resulted in a total hull loss'),
#  ('29-Mar-85', 'Lockheed CC-130H Hercules', '130330', 'Canadian Armed Forces', 5, 'Edmonton-Nam...', 'A1', 141, 'Accident resulted in a total hull loss'),
#  ('29-Mar-85', 'Lockheed CC-130H Hercules', '130331', 'Canadian Armed Forces', 5, 'Edmonton-Nam...', 'A1', 142, 'Accident resulted in a total hull loss'),
#  ('24-Jun-85', 'Lockheed C-130E Hercules', '2457', 'Brazilian AF', 7, 'near Santa Maria, RS', 'A1', 143, 'Accident resulted in a total hull loss'),
#  ('21-Nov-85', 'Lockheed C-130H-MP Hercules', 'A-1322', 'Indonesian AF', 11, 'Mount Sibayak', 'A1', 144, 'Accident resulted in a total hull loss'),
#  ('7-Mar-86', 'Lockheed C-130A Hercules', 'TT-PAB', 'Chad AF', None, '', 'A1', 146, 'Accident resulted in a total hull loss'),
#  ('2-Apr-86', 'Lockheed HC-130P Combat King', '66-0211', 'USAF', 11, 'Magdalena, NM', 'A1', 147, 'Accident resulted in a total hull loss'),
#  ('14-Aug-86', 'Lockheed C-130D-6 Hercules', 'FAH-556', 'Honduras AF', 52, 'near Mocorón-Durz...', 'A1', 148, 'Accident resulted in a total hull loss'),
#  ('9-Sep-86', 'Lockheed C-130A Hercules', '56-0468', 'USAF', 3, 'Hopkinsville...', 'A1', 149, 'Accident resulted in a total hull loss'),
#  ('1-Jul-87', 'Lockheed C-130E Hercules', '68-10945', 'USAF', 4, 'Fort Bragg, NC', 'A1', 153, 'Accident resulted in a total hull loss'),
#  ('16-Nov-87', 'Lockheed C-130A Hercules', 'TT-PAC', 'Chad AF', None, '', 'A1', 154, 'Accident resulted in a total hull loss'),
#  ('1-Dec-87', 'Lockheed C-130H Hercules', '4X-FBU/448', 'Israeli AF', 0, 'Hayoun', 'A1', 155, 'Accident resulted in a total hull loss'),
#  ('9-Dec-87', 'Lockheed LC-130R Hercules', '159131', 'US Navy', 2, 'D-59 Station', 'A1', 156, 'Accident resulted in a total hull loss'),
#  ('14-Dec-87', 'Lockheed C-130H Hercules', '2468', 'Brazilian AF', 29, 'near Fernando de ...', 'A1', 157, 'Accident resulted in a total hull loss'),
#  ('8-Jun-88', 'Lockheed C-130E Hercules', '61-2373', 'USAF', 6, 'near Greenville A...', 'A1', 158, 'Accident resulted in a total hull loss'),
#  ('17-Aug-88', 'Lockheed C-130B Hercules', '23494', 'Pakistan AF', 30, 'near Bahawalpur A...', 'A1', 159, 'Accident resulted in a total hull loss'),
#  ('29-Jan-89', 'Lockheed CC-130E Hercules', '130318', 'Canadian Armed Forces', 9, 'Fairbanks-Fo...', 'A1', 160, 'Accident resulted in a total hull loss'),
#  ('27-Mar-89', 'Lockheed C-130H Hercules', '470', 'Saudi AF', None, 'Jeddah-Princ...', 'A1', 161, 'Accident resulted in a total hull loss'),
#  ('3-Jul-89', 'Lockheed C-130B Hercules', 'FAC-1007', 'Colombian AF', 0, 'Ocaña-Aguasc...', 'A1', 162, 'Accident resulted in a total hull loss'),
#  ('9-Aug-89', 'Lockheed C-130H Hercules', '74-1681', 'USAF', 1, 'Fort Bragg, NC', 'A1', 163, 'Accident resulted in a total hull loss'),
#  ('30-Nov-89', 'Lockheed C-130H Hercules', 'TJX-AC', 'Cameroon AF', 0, 'Marseille-Pr...', 'O2', 164, 'Partial hull loss resulting from a ground fire or sabotage'),
#  ('21-Dec-89', 'Lockheed C-130A Hercules', 'TAM62', 'Bolivian AF', 22, 'Guayaramerin...', 'A1', 165, 'Accident resulted in a total hull loss'),
#  ('??-DEC-1989', 'Lockheed C-130H Hercules', '460', 'Saudi AF', None, 'Jeddah-Princ...', 'O1', 166, 'Full hull loss resulting from a ground fire or sabotage'),
#  ('20-Apr-90', 'Lockheed C-130H Hercules', '9T-TCG', 'Zaire AF', 20, 'near Kinshasa', 'A1', 168, 'Accident resulted in a total hull loss'),
#  ('25-Aug-90', 'Lockheed C-130H Hercules', 'M30-03', 'Royal Malaysian AF', 1, 'Sibu Airport...', 'A1', 169, 'Accident resulted in a total hull loss'),
#  ('31-Jan-91', 'Lockheed AC-130H Spectre', '69-6567', 'USAF', 14, 'near Ras Al Khafji', 'C1', 170, 'Full hull loss resulting from a sabotage or shootdown'),
#  ('5-Feb-91', 'Lockheed C-130H Hercules', '748', 'Hellenic AF', 63, 'near Volos-Néa An...', 'A1', 171, 'Accident resulted in a total hull loss'),
#  ('21-Mar-91', 'Lockheed C-130H Hercules', '469', 'Saudi AF', 98, 'near Rash Mishab', 'A1', 172, 'Accident resulted in a total hull loss'),
#  ('10-Jun-91', 'Lockheed C-130A Hercules', 'J6-SLQ', 'Carib Air Transport, op.for Angola Air Charter', 10, 'Luanda-4 de ...', 'A1', 173, 'Accident resulted in a total hull loss'),
#  ('5-Oct-91', 'Lockheed C-130H-30 Hercules', 'A-1324', 'Indonesian AF', 135, 'near Jakarta-Hali...', 'A1', 174, 'Accident resulted in a total hull loss'),
#  ('30-Oct-91', 'Lockheed CC-130E Hercules', '130322', 'Canadian Armed Forces', 5, 'near CFS Alert, N...', 'A1', 175, 'Accident resulted in a total hull loss'),
#  ('24-Jan-92', 'Lockheed HC-130H7 Hercules', '1706', 'US Coast Guard', 0, 'near Dutch Harbor...', 'A2', 176, 'Accident resulted in a partial hull loss'),
#  ('6-Feb-92', 'Lockheed C-130B Hercules', '58-0732', 'USAF', 17, 'near Evansville-D...', 'A1', 177, 'Accident resulted in a total hull loss'),
#  ('28-Apr-92', 'Lockheed C-130E Hercules', '64-0501', 'USAF', 9, 'Blewett Fall...', 'A1', 178, 'Accident resulted in a total hull loss'),
#  ('??-JUL-1992', 'Lockheed KC-130F Hercules', '150684', 'USMC', 0, 'Biloxi-Keesl...', 'A1', 180, 'Accident resulted in a total hull loss'),
#  ('24-Aug-92', 'Lockheed C-130B Hercules', '58-0740', 'Inter-American AF Academy', 0, 'Homestead AF...', 'O1', 181, 'Full hull loss resulting from a ground fire or sabotage'),
#  ('27-Aug-92', 'Lockheed C-130F Hercules', '149794', 'US Navy', 0, 'Guam-Agana N...', 'O1', 182, 'Full hull loss resulting from a ground fire or sabotage'),
#  ('26-Sep-92', 'Lockheed C-130H Hercules', 'NAF911', 'Nigerian AF', 159, 'near Lagos-Murtal...', 'A1', 183, 'Accident resulted in a total hull loss'),
#  ('7-Oct-92', 'Lockheed C-130E Hercules', '63-7881', 'Air National Guard', 6, 'near Berkeley Spr...', 'A1', 184, 'Accident resulted in a total hull loss'),
#  ('27-May-93', 'Lockheed Hercules C.3P (C-130K)', 'XV193', 'RAF', 9, 'Blair Athol', 'A1', 185, 'Accident resulted in a total hull loss'),
#  ('22-Jul-93', 'Lockheed CC-130E Hercules', '130321', 'Canadian Armed Forces', 5, 'near Wainwright A...', 'A1', 186, 'Accident resulted in a total hull loss'),
#  ('15-Dec-93', 'Lockheed C-130H Hercules', '4761', 'Philippine AF', 30, 'Tanag, Libma...', 'A1', 187, 'Accident resulted in a total hull loss'),
#  ('14-Mar-94', 'Lockheed AC-130H Spectre', '69-6576', 'USAF', 8, 'near Malindi', 'A1', 188, 'Accident resulted in a total hull loss'),
#  ('17-Mar-94', 'Lockheed C-130H Hercules', '21-May', 'Iran AF', 32, 'near Stepanakert', 'C1', 189, 'Full hull loss resulting from a sabotage or shootdown'),
#  ('13-Aug-94', 'Lockheed C-130A Hercules', 'N135FF', 'Hemet Valley Flying Service', 3, 'near Pearblossom, CA', 'A1', 190, 'Accident resulted in a total hull loss'),
#  ('14-Oct-94', 'Lockheed C-130E Hercules', '2460', 'Brazilian AF', 21, 'Formosa do R...', 'A1', 191, 'Accident resulted in a total hull loss'),
#  ('31-Dec-94', 'Lockheed C-130B Hercules', 'TAM67', 'Bolivian AF', None, 'near Trinidad', 'A1', 192, 'Accident resulted in a total hull loss'),
#  ('13-May-95', 'Lockheed C-130E Hercules', '62-1838', 'USAF', 6, 'Bliss Canyon...', 'A1', 193, 'Accident resulted in a total hull loss'),
#  ('15-May-96', 'Lockheed C-130H Hercules', 'TC-67', 'Argentine AF', 0, 'Tandil Airpo...', 'A1', 195, 'Accident resulted in a total hull loss'),
#  ('15-Jul-96', 'Lockheed C-130H Hercules', 'CH-06', 'Belgian AF', 34, 'Eindhoven Ai...', 'A1', 196, 'Accident resulted in a total hull loss'),
#  ('17-Aug-96', 'Lockheed C-130H Hercules', '74-1662', 'USAF', 9, 'near Jackson Hole...', 'A1', 197, 'Accident resulted in a total hull loss'),
#  ('22-Nov-96', 'Lockheed HC-130P Combat King', '64-14856', 'USAF', 10, 'near Cape Mendoci...', 'A1', 198, 'Accident resulted in a total hull loss'),
#  ('1-Apr-97', 'Lockheed C-130H Hercules', '88-4408', 'USAF', 3, 'Tegucigalpa-...', 'A1', 200, 'Accident resulted in a total hull loss'),
#  ('16-Apr-97', 'Lockheed C-130H Hercules', '5U-MBD', 'Niger Armed Forces', 14, 'near Niamey Airpo...', 'A1', 201, 'Accident resulted in a total hull loss'),
#  ('??-MAY-1997', 'Lockheed C-130A Hercules', '55-0035', 'Mexican AF', None, '', 'U1', 202, 'Hull status after incident is unknown'),
#  ('10-Oct-97', 'Lockheed C-130H Hercules', '1310', 'Republic of China AF', 5, 'Taipei-Songs...', 'A1', 203, 'Accident resulted in a total hull loss'),
#  ('20-Dec-97', 'Lockheed C-130H Hercules', '750', 'Hellenic AF', 5, 'Pastra Mountain', 'A1', 204, 'Accident resulted in a total hull loss'),
#  ('10-Sep-98', 'Lockheed C-130B Hercules', '23491', 'Pakistan AF', 0, 'Islamabad-Ch...', 'O1', 205, 'Full hull loss resulting from a ground fire or sabotage'),
#  ('10-Sep-98', 'Lockheed C-130B Hercules', '24143', 'Pakistan AF', 5, 'Islamabad-Ch...', 'A1', 206, 'Accident resulted in a total hull loss'),
#  ('??-???-1998', 'Lockheed KC-130F Hercules', '149807', 'USMC', 0, 'unknown', 'A1', 207, 'Accident resulted in a total hull loss'),
#  ('11-Jun-99', 'Lockheed Hercules C.1 (C-130K)', 'XV298', 'RAF', 0, 'Kukes', 'A1', 208, 'Accident resulted in a total hull loss'),
#  ('17-Sep-99', 'Lockheed C-130A Hercules', '3610', 'Mexican AF', 5, 'near Zempoala', 'A1', 209, 'Accident resulted in a total hull loss'),
#  ('10-Dec-99', 'Lockheed C-130E Hercules', '63-7854', 'USAF', 3, 'Kuwait Inter...', 'A1', 210, 'Accident resulted in a total hull loss'),
#  ('14-Jan-00', 'Lockheed C-130B Hercules', 'TAM60', 'Bolivian AF', 5, 'Chimore Airport', 'A1', 211, 'Accident resulted in a total hull loss'),
#  ('??-MAR-2000', 'Lockheed C-130H Hercules', 'NAF914', 'Nigerian AF', 0, 'Lagos-Murtal...', 'A1', 213, 'Accident resulted in a total hull loss'),
#  ('26-Jul-00', 'Lockheed C-130H Hercules', '348', 'Jordanian AF', 13, 'near Mafraq-King ...', 'A1', 214, 'Accident resulted in a total hull loss'),
#  ('6-Sep-00', 'Lockheed C-130A Hercules', 'N116TG', 'T & G Aviation', 2, 'near Aubenas', 'A1', 215, 'Accident resulted in a total hull loss'),
#  ('5-Sep-01', 'Lockheed C-130E Hercules', '68-10934', 'USAF', 0, 'near Laurinburg, NC', 'A2', 216, 'Accident resulted in a partial hull loss'),
#  ('27-Sep-01', 'Lockheed C-130H Hercules', '2455', 'Brazilian AF', 9, 'near Rio de Janei...', 'A1', 217, 'Accident resulted in a total hull loss'),
#  ('9-Jan-02', 'Lockheed KC-130R Hercules', '160021', 'USMC', 7, 'near Shamsi', 'A1', 218, 'Accident resulted in a total hull loss'),
#  ('11-Feb-02', 'Lockheed KC-130F Hercules', '148895', 'USMC', 0, 'near Twentynine P...', 'A1', 219, 'Accident resulted in a total hull loss'),
#  ('13-Feb-02', 'Lockheed MC-130P Combat Shadow', '66-0213', 'USAF', 0, 'Hindu Kush m...', 'A1', 220, 'Accident resulted in a total hull loss'),
#  ('12-Jun-02', 'Lockheed MC-130H Combat Talon II', '84-0475', 'USAF', 3, 'near Gardez', 'A1', 221, 'Accident resulted in a total hull loss'),
#  ('17-Jun-02', 'Lockheed C-130A Hercules', 'N130HP', 'Hawkins & Powers', 3, 'Walker, CA', 'A1', 222, 'Accident resulted in a total hull loss'),
#  ('7-Aug-02', 'Lockheed MC-130H Combat Talon II', '90-0161', 'USAF', 10, 'near Caguas', 'A1', 223, 'Accident resulted in a total hull loss'),
#  ('30-Jun-03', 'Lockheed C-130H Hercules', '7T-WHQ', 'Algerian AF', 15, 'Blida', 'A1', 225, 'Accident resulted in a total hull loss'),
#  ('19-Sep-03', 'Lockheed C-130A Hercules', '3603', 'Mexican AF', 6, 'near La Quemada', 'A1', 226, 'Accident resulted in a total hull loss'),
#  ('5-Mar-04', 'Lockheed C-130H Hercules', 'L8-2/23', 'Thai AF', 0, 'Hat Yai Airp...', 'A2', 227, 'Accident resulted in a partial hull loss'),
#  ('??-JUL-2004', 'Lockheed KC-130F Hercules', '149811', 'USMC', None, 'unknown', 'U1', 229, 'Hull status after incident is unknown'),
#  ('28-Sep-04', 'Lockheed C-130H Hercules', '84-0211', 'USAF', 0, 'Wilmington-N...', 'O1', 232, 'Full hull loss resulting from a ground fire or sabotage'),
#  ('29-Dec-04', 'Lockheed MC-130H Combat Talon II', '85-0012', 'USAF', 0, 'Qayyarah Air...', 'A1', 233, 'Accident resulted in a total hull loss'),
#  ('30-Jan-05', 'Lockheed Hercules C.1 (C-130K)', 'XV179', 'RAF', 10, 'near Al Taji', 'C1', 234, 'Full hull loss resulting from a sabotage or shootdown'),
#  ('31-Mar-05', 'Lockheed MC-130H Combat Talon II', '87-0127', 'USAF', 9, 'near Rovie', 'A1', 235, 'Accident resulted in a total hull loss'),
#  ('6-Dec-05', 'Lockheed C-130E Hercules', '19-May', 'Iran AF', 106, 'Tehran', 'A1', 236, 'Accident resulted in a total hull loss'),
#  ('14-Apr-06', 'Lockheed C-130H Hercules', '9T-TCB', 'D.R. Congo AF', 0, "Kinshasa-N'D...", 'A2', 237, 'Accident resulted in a partial hull loss'),
#  ('5-May-06', 'Lockheed C-130H Hercules', 'CH-02', 'Belgian AF', 0, 'Brussel-Zave...', 'O1', 238, 'Full hull loss resulting from a ground fire or sabotage'),
#  ('24-May-06', 'Lockheed Hercules C.1P (C-130K)', 'XV206', 'RAF', 0, 'Bost/Lashkar...', 'A1', 239, 'Accident resulted in a total hull loss'),
#  ('11-Jun-06', 'Lockheed C-130H Hercules', 'TT-PAF', 'Chad AF', 5, 'Abéché Airpo...', 'A1', 240, 'Accident resulted in a total hull loss'),
#  ('28-Jun-06', 'Lockheed HC-130H Hercules', '1710', 'US Coast Guard', 0, 'Saint Paul I...', 'A1', 241, 'Accident resulted in a total hull loss'),
#  ('17-Jul-06', 'Lockheed C-130E Hercules', '63-7853', 'USAF', 0, 'Al Asad Air ...', 'A2', 242, 'Accident resulted in a partial hull loss'),
#  ('12-Feb-07', 'Lockheed Hercules C.4 (C-130J-30)', 'ZH876', 'RAF', 0, 'near Al-Amarah', 'C1', 243, 'Full hull loss resulting from a sabotage or shootdown'),
#  ('29-Aug-07', 'Lockheed Hercules C.1P (C-130K)', 'XV205', 'RAF', 0, 'within Helmand Prov...', 'A1', 244, 'Accident resulted in a total hull loss'),
#  ('27-Jun-08', 'Lockheed C-130H2 Hercules', '86-0412', 'USAF', 0, 'near Baghdad Inte...', 'A1', 245, 'Accident resulted in a total hull loss'),
#  ('5-Aug-08', 'Lockheed C-130H Hercules', '1212', 'United Arab Emirates AF', 0, 'Bagram Air B...', 'A1', 246, 'Accident resulted in a total hull loss'),
#  ('24-Feb-09', 'Lockheed C-130H Hercules', 'SU-BAC/1272', 'Egyptian AF', 0, 'unknown', 'A1', 247, 'Accident resulted in a total hull loss'),
#  ('11-May-09', 'Lockheed C-130B Hercules', 'A-1302', 'Indonesian AF', 0, 'Wamena Airpo...', 'A1', 248, 'Accident resulted in a total hull loss'),
#  ('29-Oct-09', 'Lockheed HC-130H Hercules', '1705', 'US Coast Guard', 7, 'near San Clemente...', 'A1', 249, 'Accident resulted in a total hull loss'),
#  ('23-Nov-09', 'Lockheed KC-130J Hercules', 'MM62176', 'Italian AF', 5, 'Le Rene, nea...', 'A1', 250, 'Accident resulted in a total hull loss'),
#  ('25-Jan-10', 'Lockheed C-130B Hercules', '404', 'South African AF', 0, 'Waterkloof A...', 'A1', 251, 'Accident resulted in a total hull loss'),
#  ('2-Feb-10', 'Lockheed C-130E Hercules', '1506', 'Polish AF', 0, 'Mazar-I-Shar...', 'A2', 252, 'Accident resulted in a partial hull loss'),
#  ('6-May-10', 'Lockheed Hercules C.3A (C-130K)', 'XV304', 'RAF', 0, 'Brize Norton...', 'A1', 253, 'Accident resulted in a total hull loss'),
#  ('18-Nov-10', 'Lockheed C-130H Hercules', '7O-ADD/1160', 'Yemen AF', 0, "Sana'a Inter...", 'A2', 254, 'Accident resulted in a partial hull loss'),
#  ('19-Nov-10', 'Lockheed C-130H-30 Hercules', '7T-WHA', 'Algerian AF', 0, 'Paris-Le Bou...', 'A2', 255, 'Accident resulted in a partial hull loss'),
#  ('25-Apr-11', 'Lockheed C-130E Hercules', '62-1806', 'USAF', 0, 'Jacksonville...', 'O1', 256, 'Full hull loss resulting from a ground fire or sabotage'),
#  ('25-Apr-11', 'Lockheed C-130E Hercules', '62-1851', 'USAF', 0, 'Jacksonville...', 'O1', 257, 'Full hull loss resulting from a ground fire or sabotage'),
#  ('26-Jul-11', 'Lockheed C-130H Hercules', 'CNA-OQ', 'Moroccan AF', 80, 'near Goulimime Ai...', 'A1', 258, 'Accident resulted in a total hull loss'),
#  ('21-Feb-12', 'Lockheed CC-130H(T) Hercules', '130342', 'RCAF', 0, 'Key West NAS...', 'A1', 260, 'Accident resulted in a total hull loss'),
#  ('15-Mar-12', 'Lockheed C-130J-30 Super Hercules', '5630', 'Norwegian AF', 5, 'Mount Kebnek...', 'A1', 261, 'Accident resulted in a total hull loss'),
#  ('1-Jul-12', 'Lockheed C-130H Hercules', '93-1458', 'USAF', 4, 'near Edgemont, SD', 'A1', 262, 'Accident resulted in a total hull loss'),
#  ('11-Dec-12', 'Lockheed HC-130P Hercules', '65-0981', 'USAF', None, 'within Afghanistan', 'U1', 263, 'Hull status after incident is unknown'),
#  ('19-May-13', 'Lockheed C-130J-30 Super Hercules', 'Apr-44', 'USAF', 0, 'Forward Oper...', 'A1', 264, 'Accident resulted in a total hull loss'),
#  ('??-MAY-2013', 'Lockheed C-130H Hercules', 'T.10-02', 'Spanish AF', 0, 'unknown', 'U1', 265, 'Hull status after incident is unknown'),
#  ('11-Feb-14', 'Lockheed C-130H-30 Hercules', '7T-WHM', 'Algerian AF', 76, 'near Aïn Kercha', 'A1', 266, 'Accident resulted in a total hull loss'),
#  ('28-Mar-14', 'Lockheed C-130J-30 Super Hercules', 'KC-3803', 'Indian AF', 5, 'Karauli dist...', 'A1', 267, 'Accident resulted in a total hull loss'),
#  ('22-Jul-14', 'Lockheed C-130J Super Hercules', 'MM62190', 'Italian AF', 0, 'Herat Airpor...', 'A1', 268, 'Accident resulted in a total hull loss'),
#  ('21-Sep-14', 'Lockheed C-130H Hercules', 'SU-BAT/1287', 'Egyptian AF', 6, 'Kom Ashwin, ...', 'A1', 269, 'Accident resulted in a total hull loss'),
#  ('27-Nov-14', 'Lockheed C-130M Hercules', '2470', 'Brazilian AF', 0, 'Teniente Rod...', 'A2', 270, 'Accident resulted in a partial hull loss'),
#  ('1-Dec-14', 'Lockheed C-130H Hercules', '88-4404', 'USAF', 0, 'near Mackall AAF, NC', 'A1', 271, 'Accident resulted in a total hull loss'),
#  ('13-Apr-15', 'Lockheed NC-130F Hercules', '148897', 'USMC', 0, 'Port Hueneme...', 'A1', 272, 'Accident resulted in a total hull loss'),
#  ('21-Apr-15', 'Lockheed AC-130J Ghostrider', '10-Sep', 'USAF', 0, 'near Valparaiso-E...', 'A1', 273, 'Accident resulted in a total hull loss'),
#  ('30-Jun-15', 'Lockheed C-130B Hercules', 'A-1310', 'Indonesian AF', 139, 'near Medan-Soewon...', 'A1', 274, 'Accident resulted in a total hull loss'),
#  ('7-Jul-15', 'Lockheed C-130H Hercules', '79-0478', 'USAF', 0, 'Baghdad Inte...', 'A1', 275, 'Accident resulted in a total hull loss'),
#  ('2-Oct-15', 'Lockheed C-130J-30 Super Hercules', 'Aug-74', 'USAF', 14, 'Jalalabad Ai...', 'A1', 276, 'Accident resulted in a total hull loss'),
#  ('11-Jul-16', 'Lockheed C-130H Hercules', '16804', 'Portuguese AF', 3, 'Montijo Air ...', 'A1', 277, 'Accident resulted in a total hull loss'),
#  ('19-Oct-16', 'Lockheed C-130B Hercules', 'FAC-1014', 'Colombian AF', 1, 'near Apiay', 'A1', 278, 'Accident resulted in a total hull loss'),
#  ('18-Dec-16', 'Lockheed C-130H Hercules', 'A-1334', 'Indonesian AF', 13, 'near Wamena Airpo...', 'A1', 279, 'Accident resulted in a total hull loss'),
#  ('10-Jul-17', 'Lockheed KC-130T Hercules', '165000', 'USMC', 16, 'near Itta Bena, MS', 'A1', 280, 'Accident resulted in a total hull loss'),
#  ('25-Aug-17', 'Lockheed Hercules C.4 (C-130J-30)', 'ZH873', 'RAF', 0, 'Temporary La...', 'A1', 281, 'Accident resulted in a total hull loss'),
#  ('2-May-18', 'Lockheed WC-130H Hercules', '65-0968', 'USAF', 9, 'near Savannah/Hil...', 'A1', 283, 'Accident resulted in a total hull loss'),
#  ('3-Jun-18', 'Lockheed C-130H Hercules', '7T-WHT', 'Algerian AF', 1, 'near Biskra Airpo...', 'A1', 284, 'Accident resulted in a total hull loss'),
#  ('9-Nov-18', 'Lockheed C-130E Hercules', '4180', 'Pakistan AF', 0, 'Chaklala-PAF...', 'A1', 285, 'Accident resulted in a total hull loss'),
#  ('6-Dec-18', 'Lockheed Martin KC-130J', '167981', 'USMC', 5, 'near Muroto Cape,...', 'A1', 286, 'Accident resulted in a total hull loss'),
#  ('25-Aug-19', 'Lockheed C-130A Hercules', 'N119TG', 'International Air Response', 0, 'Santa Barbar...', 'A2', 287, 'Accident resulted in a partial hull loss'),
#  ('9-Dec-19', 'Lockheed C-130H Hercules', '990', 'Chilean AF', 38, 'near King George ...', 'A1', 288, 'Accident resulted in a total hull loss'),
#  ('9-Jan-20', 'Lockheed C-130BZ Hercules', '403', 'South African AF', 0, 'Goma Airport...', 'A1', 289, 'Accident resulted in a total hull loss'),
#  ('23-Jan-20', 'Lockheed EC-130Q Hercules', 'N134CG', 'Coulson Aviation', 3, 'near Cooma, NSW', 'A1', 290, 'Accident resulted in a total hull loss')]

# %% [markdown]
# We can know process more reliable data that we can look at further by virtue of the compromised aircrafts having known registrations. At a glance, it will be helpful to know which operators of the C130 have experienced the highest average number of fatalities (and other similar data) as a preliminarily investigatable metric. To do this, a simple SELECT statement with a GROUP BY on Operator will be used.

# %%
# %%sql
# SELECT operator, cat, AVG(fatalities) AS 'Average Fatalities', COUNT(fatalities) AS 'Total Accidents', SUM(fatalities) AS 'Total Recorded Fatalities by Accident Operator'
# FROM Known_Registrations
# GROUP BY operator
# ORDER BY AVG(fatalities) DESC;
# Out:
#  * mysql://admin:***@lmu-sql.cj7ti7dehqfe.us-east-2.rds.amazonaws.com/sql_project
# 57 rows affected.
# [('Nigerian AF', 'A1', Decimal('79.5000'), 2, Decimal('159')),
#  ('Saudi AF', 'A1', Decimal('65.0000'), 3, Decimal('195')),
#  ('Indonesian AF', 'A1', Decimal('56.2500'), 8, Decimal('450')),
#  ('Moroccan AF', 'A1', Decimal('55.0000'), 3, Decimal('165')),
#  ('Honduras AF', 'A1', Decimal('52.0000'), 1, Decimal('52')),
#  ('Venezuela AF', 'A1', Decimal('39.5000'), 2, Decimal('79')),
#  ('Chilean AF', 'A1', Decimal('38.0000'), 2, Decimal('76')),
#  ('Iran AF', 'A1', Decimal('35.8571'), 7, Decimal('251')),
#  ('Hellenic AF', 'A1', Decimal('34.0000'), 2, Decimal('68')),
#  ('Philippine AF', 'A1', Decimal('30.0000'), 1, Decimal('30')),
#  ('Zaire AF', 'A1', Decimal('29.0000'), 3, Decimal('87')),
#  ('Algerian AF', 'A2', Decimal('24.1429'), 7, Decimal('169')),
#  ('Belgian AF', 'A1', Decimal('17.0000'), 2, Decimal('34')),
#  ('Niger Armed Forces', 'A1', Decimal('14.0000'), 1, Decimal('14')),
#  ('Bolivian AF', 'A1', Decimal('13.5000'), 2, Decimal('27')),
#  ('Jordanian AF', 'A1', Decimal('13.0000'), 1, Decimal('13')),
#  ('Brazilian AF', 'A2', Decimal('11.0000'), 6, Decimal('66')),
#  ('Israeli AF', 'A1', Decimal('10.0000'), 2, Decimal('20')),
#  ('Carib Air Transport, op.for Angola Air Charter', 'A1', Decimal('10.0000'), 1, Decimal('10')),
#  ('Italian AF', 'A1', Decimal('9.0000'), 6, Decimal('54')),
#  ('Ecuador Air Force', 'A1', Decimal('9.0000'), 2, Decimal('18')),
#  ('USAF', 'O1', Decimal('6.5882'), 85, Decimal('560')),
#  ('Canadian Armed Forces', 'A1', Decimal('6.2857'), 7, Decimal('44')),
#  ('Air National Guard', 'A1', Decimal('6.0000'), 1, Decimal('6')),
#  ('RAF', 'A1', Decimal('5.8462'), 13, Decimal('76')),
#  ('Mexican AF', 'U1', Decimal('5.5000'), 2, Decimal('11')),
#  ('Egyptian AF', 'A1', Decimal('5.3333'), 6, Decimal('32')),
#  ('Pakistan AF', 'A1', Decimal('5.0000'), 7, Decimal('35')),
#  ('Chad AF', 'A1', Decimal('5.0000'), 1, Decimal('5')),
#  ('Norwegian AF', 'A1', Decimal('5.0000'), 2, Decimal('10')),
#  ('Indian AF', 'A1', Decimal('5.0000'), 2, Decimal('10')),
#  ('Republic of China AF', 'A1', Decimal('5.0000'), 1, Decimal('5')),
#  ('USMC', 'A1', Decimal('4.9000'), 10, Decimal('49')),
#  ('TAB', 'A1', Decimal('4.0000'), 1, Decimal('4')),
#  ('Argentine AF', 'C1', Decimal('3.6667'), 3, Decimal('11')),
#  ('Spanish AF', 'U1', Decimal('3.3333'), 3, Decimal('10')),
#  ('US Coast Guard', 'A1', Decimal('3.2000'), 5, Decimal('16')),
#  ('Hawkins & Powers', 'A1', Decimal('3.0000'), 1, Decimal('3')),
#  ('Coulson Aviation', 'A1', Decimal('3.0000'), 2, Decimal('6')),
#  ('Hemet Valley Flying Service', 'A1', Decimal('3.0000'), 1, Decimal('3')),
#  ('Portuguese AF', 'A1', Decimal('3.0000'), 2, Decimal('6')),
#  ('US Navy', 'A1', Decimal('2.5714'), 7, Decimal('18')),
#  ('T & G Aviation', 'A1', Decimal('2.0000'), 1, Decimal('2')),
#  ('Colombian AF', 'A1', Decimal('1.7500'), 4, Decimal('7')),
#  ('Royal Malaysian AF', 'A1', Decimal('1.0000'), 1, Decimal('1')),
#  ('RCAF', 'A1', Decimal('0.0000'), 2, Decimal('0')),
#  ('South African AF', 'A1', Decimal('0.0000'), 4, Decimal('0')),
#  ('International Air Response', 'A2', Decimal('0.0000'), 2, Decimal('0')),
#  ('Polish AF', 'A2', Decimal('0.0000'), 2, Decimal('0')),
#  ('Cameroon AF', 'O2', Decimal('0.0000'), 1, Decimal('0')),
#  ('Thai AF', 'A2', Decimal('0.0000'), 1, Decimal('0')),
#  ('United Arab Emirates AF', 'A1', Decimal('0.0000'), 2, Decimal('0')),
#  ('Yemen AF', 'A2', Decimal('0.0000'), 2, Decimal('0')),
#  ('Libyan Arab Rep. Air Force', 'O1', Decimal('0.0000'), 1, Decimal('0')),
#  ('D.R. Congo AF', 'A2', Decimal('0.0000'), 1, Decimal('0')),
#  ('Vietnam Air Force - VNAF', 'O1', Decimal('0.0000'), 1, Decimal('0')),
#  ('Inter-American AF Academy', 'O1', Decimal('0.0000'), 1, Decimal('0'))]

# %% [markdown]
# SQL Exploratory Question, Business Justification, and Statement(s) #2:
#
# QUESTION:
# All three types of aircraft I chose to collect data on (C130, C160, and AN12) are four-rotor turboprop aircraft and have a standard MINIMUM crew of five (two pilots, a navigator, flight engineer and loadmaster) and a MAXIMUM of 92 troops, thus making total safe occupancy 97 total. With these known min and max values, is it possible that a number of occupants above the maximum threshold is a causal factor in a category [a/o/u/c]1 accident?
#
# SQL STATEMENT:
# To answer this question, let us first create a VIEW that contains a UNION join of all three aircraft data tables for ease of inter-table data manipulation. Then, a simple SELECT statement will be used to determine incident data from operators flying beyond the maximum occupancy.
#
# BUSINESS JUSTIFICATION:
# To save lives, generate revenue from training, and standardize pilot training across this airframe and the nations that use it, being able to identify which operators are improperly loading their aircrafts is crucial. Moreover, identifying operators overloading their aircrafts is useful information for governing bodies like the NTSB to use when conducting accident investigations. The FAA or similar organizations could find this information useful when revoking flying permits or restricting airspace to certain unsafe operators.

# %%
# %%sql
# CREATE VIEW Occupancy_Limitations AS
# SELECT *
# FROM c130_1
# UNION
# SELECT *
# FROM c160
# UNION
# SELECT *
# FROM an12;
# Out:
#  * mysql://admin:***@lmu-sql.cj7ti7dehqfe.us-east-2.rds.amazonaws.com/sql_project
# (MySQLdb._exceptions.OperationalError) (1050, "Table 'Occupancy_Limitations' already exists")
# [SQL: CREATE VIEW Occupancy_Limitations AS
# SELECT *
# FROM c130_1
# UNION
# SELECT *
# FROM c160
# UNION
# SELECT *
# FROM an12;]
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %% [markdown]
# From here, a simple SELECT statement on the VIEW can give us an idea of incident data from all three tables where a plane was flying above its maximum occupancy threshold.

# %%
# %%sql
# SELECT *
# FROM Occupancy_Limitations
# WHERE
# 	(fatalities > 97) AND
# 	registration !=''
# 	AND (cat = 'A1' OR
# 		cat = 'C1' OR
# 		cat = 'O1' OR
# 		cat = 'U1')
# ORDER BY fatalities DESC;
# Out:
#  * mysql://admin:***@lmu-sql.cj7ti7dehqfe.us-east-2.rds.amazonaws.com/sql_project
# 8 rows affected.
# [('26-Sep-92', 'Lockheed C-130H Hercules', 'NAF911', 'Nigerian AF', 159, 'near Lagos-Murtal...', 'A1', 183),
#  ('30-Jun-15', 'Lockheed C-130B Hercules', 'A-1310', 'Indonesian AF', 139, 'near Medan-Soewon...', 'A1', 29),
#  ('30-Jun-15', 'Lockheed C-130B Hercules', 'A-1310', 'Indonesian AF', 139, 'near Medan-Soewon...', 'A1', 274),
#  ('5-Oct-91', 'Lockheed C-130H-30 Hercules', 'A-1324', 'Indonesian AF', 135, 'near Jakarta-Hali...', 'A1', 174),
#  ('7-Jun-17', 'Shaanxi Y-8F-200W', '5820', 'Myanmar Air Force', 122, 'near Dawei', 'A1', 254),
#  ('6-Dec-05', 'Lockheed C-130E Hercules', '19-May', 'Iran AF', 106, 'Tehran', 'A1', 236),
#  ('7-Feb-68', 'Antonov An-12BP', 'BL534', 'Indian AF', 102, 'Dhaka Glacier', 'A1', 26),
#  ('21-Mar-91', 'Lockheed C-130H Hercules', '469', 'Saudi AF', 98, 'near Rash Mishab', 'A1', 172)]

# %% [markdown]
# SQL Exploratory Question, Business Justification, and Statement(s) #3:
#
# QUESTION:
# For this question, I am going to focus again on safety record based on operator, but this time rather than constraining our findings to operators who were guilty of overloading their airframe's capacity, we are going to try and compare number of incidents against average number of fatalities of those incidents by operator.
#
# SQL STATEMENT:
# To acquire this data, I will be using aggregate WINDOW functions (COUNT and AVG), including a PARTITION BY operator to GROUP data by DISTINCT operator. This query will be run on the previously created VIEW table named Occupancy_Limitiations – it is a UNIONED aggregation of all data across all three similar airframes.
#
# BUSINESS JUSTIFICATION:
# This collection of data will help provide insight into the actual data integrity of large AVG or COUNTs of numbers of fatalities by displaying the two aggregate function yields side by side. Again, this would be very helpful information to the producer of the aircraft, defense contractors, or pilot training firms to identify potential customers that could use extra training. More importantly however, the lives saved by proper data-driven action supercedes the business application and hopefully this makes that process one step easier.

# %%
# %%sql
# SELECT
# 	DISTINCT(`operator`),
# 	COUNT(fatalities) OVER(PARTITION BY `operator`) AS 	Count_Of_Incidents,
# 	AVG(fatalities) OVER(PARTITION BY `operator`) AS Avg_Number_Fatalities
# FROM Occupancy_Limitations
# WHERE registration !=''
# ORDER BY Count_Of_Incidents DESC;
# Out:
#  * mysql://admin:***@lmu-sql.cj7ti7dehqfe.us-east-2.rds.amazonaws.com/sql_project
# 180 rows affected.
# [('USAF', 85, Decimal('6.5882')),
#  ('RAF', 13, Decimal('5.8462')),
#  ('Aeroflot / Polar', 10, Decimal('4.5000')),
#  ('USMC', 10, Decimal('4.9000')),
#  ('Indonesian AF', 9, Decimal('51.4444')),
#  ('Soviet AF', 8, Decimal('9.5000')),
#  ('Algerian AF', 7, Decimal('24.1429')),
#  ('Canadian Armed Forces', 7, Decimal('6.2857')),
#  ('Indian AF', 7, Decimal('32.0000')),
#  ('Iran AF', 7, Decimal('35.8571')),
#  ('Pakistan AF', 7, Decimal('5.0000')),
#  ('US Navy', 7, Decimal('2.5714')),
#  ('Brazilian AF', 6, Decimal('11.0000')),
#  ('Egyptian AF', 6, Decimal('5.3333')),
#  ('French AF', 6, Decimal('2.1667')),
#  ('Italian AF', 6, Decimal('9.0000')),
#  ('Sarit Airlines', 6, Decimal('2.8333')),
#  ('Aeroflot / East Siberia', 5, Decimal('2.6000')),
#  ('Aeroflot / International', 5, Decimal('2.8000')),
#  ('Aeroflot / Yakutsk', 5, Decimal('3.2000')),
#  ('Russian AF', 5, Decimal('4.8000')),
#  ('Unknown', 5, Decimal('0.0000')),
#  ('US Coast Guard', 5, Decimal('3.2000')),
#  ('Angolan AF', 4, Decimal('2.2500')),
#  ('Colombian AF', 4, Decimal('1.7500')),
#  ('German AF', 4, Decimal('14.7500')),
#  ('South African AF', 4, Decimal('0.0000')),
#  ('Aeroflot / Krasnoyarsk', 3, Decimal('4.0000')),
#  ('Argentine AF', 3, Decimal('3.6667')),
#  ('China Air Force', 3, Decimal('11.3333')),
#  ('Ethiopian AF', 3, Decimal('18.6667')),
#  ('Moroccan AF', 3, Decimal('55.0000')),
#  ('Saudi AF', 3, Decimal('65.0000')),
#  ('Spanish AF', 3, Decimal('3.3333')),
#  ('Ukraine Air Alliance', 3, Decimal('4.0000')),
#  ('Zaire AF', 3, Decimal('29.0000')),
#  ('Aero Fret Business', 2, Decimal('3.0000')),
#  ('Aeroflot / Komi', 2, Decimal('6.5000')),
#  ('Aerolift', 2, Decimal('2.5000')),
#  ('Alada', 2, Decimal('8.5000')),
#  ('Ariana Afghan Airlines', 2, Decimal('0.0000')),
#  ('Balkan Bulgarian', 2, Decimal('0.0000')),
#  ('Belgian AF', 2, Decimal('17.0000')),
#  ('Bolivian AF', 2, Decimal('13.5000')),
#  ('British Gulf International Airlines', 2, Decimal('3.5000')),
#  ('Cavok Air', 2, Decimal('0.0000')),
#  ('Chilean AF', 2, Decimal('38.0000')),
#  ('Coulson Aviation', 2, Decimal('3.0000')),
#  ('D.R. Congo AF', 2, Decimal('4.0000')),
#  ('Ecuador Air Force', 2, Decimal('9.0000')),
#  ('El Magal Aviation', 2, Decimal('3.5000')),
#  ('Hellenic AF', 2, Decimal('34.0000')),
#  ('International Air Response', 2, Decimal('0.0000')),
#  ('Israeli AF', 2, Decimal('10.0000')),
#  ('Juba Air Cargo', 2, Decimal('4.5000')),
#  ('Manunggal Air', 2, Decimal('0.5000')),
#  ('MAP Kom na Amu APO', 2, Decimal('9.0000')),
#  ('Mexican AF', 2, Decimal('5.5000')),
#  ('MOM/Polyot', 2, Decimal('4.5000')),
#  ('Nigerian AF', 2, Decimal('79.5000')),
#  ('Norwegian AF', 2, Decimal('5.0000')),
#  ('operator', 2, Decimal('0.0000')),
#  ('Polish AF', 2, Decimal('0.0000')),
#  ('Portuguese AF', 2, Decimal('3.0000')),
#  ('Pulkovo', 2, Decimal('6.5000')),
#  ('RCAF', 2, Decimal('0.0000')),
#  ('Silk Way', 2, Decimal('3.5000')),
#  ('Sri Lanka AF', 2, Decimal('12.0000')),
#  ('United Arab Emirates AF', 2, Decimal('0.0000')),
#  ('Venezuela AF', 2, Decimal('39.5000')),
#  ('Veteran Airline', 2, Decimal('0.0000')),
#  ('Yemen AF', 2, Decimal('0.0000')),
#  (', op.for UN', 1, Decimal('0.0000')),
#  ('748 Air Services', 1, Decimal('0.0000')),
#  ('ACA-Ancargo Air', 1, Decimal('4.0000')),
#  ('Aero Tropical', 1, Decimal('8.0000')),
#  ('Aéro-Service', 1, Decimal('0.0000')),
#  ('Aerocom, op.for Pacific Air Express', 1, Decimal('0.0000')),
#  ('Aeroflot / North Kavkaz', 1, Decimal('0.0000')),
#  ('Aeroflot / Privolzhsk', 1, Decimal('0.0000')),
#  ('Aeroflot / Tyumen', 1, Decimal('7.0000')),
#  ('Aeroflot / Uralsk', 1, Decimal('0.0000')),
#  ('Aeronika', 1, Decimal('23.0000')),
#  ('Aerovista Airlines', 1, Decimal('0.0000')),
#  ('Africa West Airlines', 1, Decimal('0.0000')),
#  ('Air Luxor, lsf Air Sofia', 1, Decimal('7.0000')),
#  ('Air Mark Aviation', 1, Decimal('0.0000')),
#  ('Air National Guard', 1, Decimal('6.0000')),
#  ('Air Sofia, op.for Mandala Airlines', 1, Decimal('0.0000')),
#  ('Air West', 1, Decimal('0.0000')),
#  ('Allied Services Limited, lsf Asia Airways', 1, Decimal('41.0000')),
#  ('Almaty Aviation, op.for Interisland Airlines', 1, Decimal('3.0000')),
#  ('Amuraviatrans', 1, Decimal('0.0000')),
#  ('Antey, op.for Sky Cabs', 1, Decimal('9.0000')),
#  ('Antonov Design Bureau', 1, Decimal('0.0000')),
#  ('ATMA Airlines', 1, Decimal('0.0000')),
#  ('ATRAN', 1, Decimal('7.0000')),
#  ('Avia', 1, Decimal('0.0000')),
#  ('Aviakor', 1, Decimal('0.0000')),
#  ('Aviaobshchemash', 1, Decimal('0.0000')),
#  ('AZZA Transport, op.for Sudan AF', 1, Decimal('15.0000')),
#  ('Cameroon AF', 1, Decimal('0.0000')),
#  ('Carib Air Transport, op.for Angola Air Charter', 1, Decimal('10.0000')),
#  ('Centrafrican Airlines', 1, Decimal('3.0000')),
#  ('Chad AF', 1, Decimal('5.0000')),
#  ('Cubana', 1, Decimal('10.0000')),
#  ('East Wing', 1, Decimal('0.0000')),
#  ('ELIIP', 1, Decimal('0.0000')),
#  ('Galaxy Incorporation, lsf Transaviaservice', 1, Decimal('8.0000')),
#  ('GosNII GA, op.for Savanair (Angola)', 1, Decimal('7.0000')),
#  ('Hawkins & Powers', 1, Decimal('3.0000')),
#  ('Helitours, op.for Sri Lanka AF', 1, Decimal('5.0000')),
#  ('Hemet Valley Flying Service', 1, Decimal('3.0000')),
#  ('Honduras AF', 1, Decimal('52.0000')),
#  ('Imtrec Aviation', 1, Decimal('0.0000')),
#  ('Inter Trans Air', 1, Decimal('0.0000')),
#  ('Inter-American AF Academy', 1, Decimal('0.0000')),
#  ('Intercity Airways', 1, Decimal('0.0000')),
#  ('Iraqi Airways', 1, Decimal('0.0000')),
#  ('Irbis, op.for Air BAS Transportation', 1, Decimal('0.0000')),
#  ('Irkut', 1, Decimal('9.0000')),
#  ('Jordanian AF', 1, Decimal('13.0000')),
#  ('Khabarovsk Avia', 1, Decimal('0.0000')),
#  ('Khors Air', 1, Decimal('10.0000')),
#  ('KnAAPO, op.for Avis Amur', 1, Decimal('11.0000')),
#  ('KNG Transavia Cargo, op.for Business and Cargo Company', 1, Decimal('7.0000')),
#  ('Komi Avia', 1, Decimal('0.0000')),
#  ('Krasnoyarskie Avialinii', 1, Decimal('10.0000')),
#  ('Libyan Arab Rep. Air Force', 1, Decimal('0.0000')),
#  ('LOT', 1, Decimal('9.0000')),
#  ('Magadanaerogruz', 1, Decimal('0.0000')),
#  ('Mango Airlines', 1, Decimal('6.0000')),
#  ('MAP Kiev MSZ', 1, Decimal('0.0000')),
#  ('MAP Rostov VPO', 1, Decimal('0.0000')),
#  ('Moskovia Airlines', 1, Decimal('9.0000')),
#  ('Motor Sich', 1, Decimal('0.0000')),
#  ('Myanmar Air Force', 1, Decimal('122.0000')),
#  ('Niger Armed Forces', 1, Decimal('14.0000')),
#  ('Norilsk Air Enterprise', 1, Decimal('0.0000')),
#  ('Pecotox Air', 1, Decimal('0.0000')),
#  ('Penza Air Enterprise', 1, Decimal('0.0000')),
#  ('Petrolada', 1, Decimal('0.0000')),
#  ('Philippine AF', 1, Decimal('30.0000')),
#  ('Phoenix Avia', 1, Decimal('0.0000')),
#  ('Republic of China AF', 1, Decimal('5.0000')),
#  ('Royal Malaysian AF', 1, Decimal('1.0000')),
#  ('Sakha Avia', 1, Decimal('0.0000')),
#  ('Santa Cruz Imperial, op.for Savanair (Angola)', 1, Decimal('24.0000')),
#  ('Savanair (Angola)', 1, Decimal('1.0000')),
#  ('Services Air', 1, Decimal('6.0000')),
#  ('Showa Air', 1, Decimal('0.0000')),
#  ('Sigi Air Cargo', 1, Decimal('0.0000')),
#  ('Soviet Navy', 1, Decimal('24.0000')),
#  ('Special Cargo Airlines', 1, Decimal('1.0000')),
#  ('Styron Trading', 1, Decimal('0.0000')),
#  ('Sudan AF', 1, Decimal('18.0000')),
#  ('T & G Aviation', 1, Decimal('2.0000')),
#  ('TAB', 1, Decimal('4.0000')),
#  ('Techaviaservice', 1, Decimal('13.0000')),
#  ('Thai AF', 1, Decimal('0.0000')),
#  ('Tiramavia', 1, Decimal('1.0000')),
#  ('Trans Air Congo', 1, Decimal('23.0000')),
#  ('Turkish AF', 1, Decimal('0.0000')),
#  ('Tyumenaviatrans', 1, Decimal('0.0000')),
#  ('UN', 1, Decimal('1.0000')),
#  ('United Arabian Airlines, op.for AZZA Transport', 1, Decimal('0.0000')),
#  ('Victoria Air', 1, Decimal('27.0000')),
#  ('Vietnam Air Force - VNAF', 1, Decimal('0.0000')),
#  ('Viluy', 1, Decimal('13.0000')),
#  ('Volare', 1, Decimal('8.0000')),
#  ('Volga-Dnepr', 1, Decimal('8.0000')),
#  ('Wimbi Dira Airways', 1, Decimal('2.0000')),
#  ('Yugoslav AF', 1, Decimal('7.0000')),
#  ('Zanex', 1, Decimal('1.0000')),
#  ('Zapolyarye Airlines', 1, Decimal('0.0000')),
#  ('Aeroflot', 0, None),
#  ('Aeroflot / Magadan', 0, None),
#  ('Aeroflot / Moscow', 0, None),
#  ('Aeroflot / Northern', 0, None),
#  ('Angolan Government', 0, None)]
